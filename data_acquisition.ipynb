# %%
import pandas as pd

# %%
#read json files and then convert them into dataframes

df_cancelled = pd.read_json('Data/cancelled.json')
df_noncancelled = pd.read_json('Data/noncancelled.json')
df_sailorapp = pd.read_json('Data/sailorapp.json')

# %%
df_cancelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2411 entries, 0 to 2410
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Status       2411 non-null   object
#  1   Description  2411 non-null   object
#  2   Comments     2411 non-null   object
#  3   Priority     2411 non-null   object
#  4   RootCause    2411 non-null   object
#  5   Reporter     2411 non-null   object
#  6   IssueKey     2411 non-null   object
#  7   Summary      2411 non-null   object
#  8   Sprint       2411 non-null   object
#  9   Component    2411 non-null   object
#  10  Application  2411 non-null   object
#  11  Assigne      2411 non-null   object
# dtypes: object(12)
# memory usage: 226.2+ KB

# %%
df_noncancelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3278 entries, 0 to 3277
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Status       3278 non-null   object
#  1   Description  3278 non-null   object
#  2   Comments     3278 non-null   object
#  3   Priority     3278 non-null   object
#  4   RootCause    3278 non-null   object
#  5   Reporter     3278 non-null   object
#  6   IssueKey     3278 non-null   object
#  7   Summary      3278 non-null   object
#  8   Sprint       3278 non-null   object
#  9   Component    3278 non-null   object
#  10  Application  3278 non-null   object
#  11  Assigne      3278 non-null   object
# dtypes: object(12)
# memory usage: 307.4+ KB

# %%
df_sailorapp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5427 entries, 0 to 5426
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Status       5427 non-null   object
#  1   Description  5427 non-null   object
#  2   Comments     5427 non-null   object
#  3   Priority     5427 non-null   object
#  4   RootCause    5427 non-null   object
#  5   Reporter     5427 non-null   object
#  6   IssueKey     5427 non-null   object
#  7   Summary      5427 non-null   object
#  8   Sprint       5427 non-null   object
#  9   Application  5427 non-null   object
#  10  Assigne      5427 non-null   object
# dtypes: object(11)
# memory usage: 466.5+ KB

# %%
df_cancelled.head(100)
# Out:
#       Status                                        Description  \
# 0   Canceled  Build: PI7.6 FE + 8.2 BE Hotfix , App Version:...
# 1   Canceled  Ship parse count for housekeeping requests:\r\...
# 2   Canceled  Hi [~accountid:5ade5093027e7a2ebfcbd97e] / [~a...
# 3   Canceled  Ship side team has successfully uploaded the s...
# 4   Canceled  Hit the application url and do the booking flo...
# ..       ...                                                ...
# 95  Canceled  Steps to Reproduce:\r\n\r\n1) Launch SailorApp...
# 96  Canceled  Please have a look at the Tax &  Insurance val...
# 97  Canceled  Opened an existing sailor account which had a ...
# 98  Canceled  SSM unable to change the case owner and a "Cha...
# 99  Canceled  Orange Opportunity Panel and calendar recs are...
#
#                                              Comments     Priority RootCause  \
# 0                                                  []  P3 - Medium        NA
# ...
